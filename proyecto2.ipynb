# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar los datos
data = pd.read_csv("data.csv")

# Mostrar información general del dataset
print(data.info())
print(data.describe())

# Calcular la matriz de correlación
correlation_matrix = data.corr()

# Visualizar la matriz de correlación con un heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Matriz de Correlación")
plt.show()

# Visualizar la relación de cada variable con AQI
for column in data.columns:
    if column != "AQI":  # Suponiendo que "AQI" es la variable objetivo
        plt.figure(figsize=(6, 4))
        sns.scatterplot(x=data[column], y=data["AQI"])
        plt.xlabel(column)
        plt.ylabel("AQI")
        plt.title(f"Relación entre {column} y AQI")
        plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   X1      100000 non-null  float64
#  1   X2      100000 non-null  float64
#  2   X3      100000 non-null  float64
#  3   X4      100000 non-null  float64
#  4   X5      100000 non-null  float64
#  5   y       100000 non-null  float64
# dtypes: float64(6)
# memory usage: 4.6 MB
# None
#                   X1             X2             X3             X4  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       -0.003602       0.004257      -0.004177      -0.006457
# std         1.001869       0.999310       1.001242       1.002268
# min        -4.295391      -4.465604      -4.829436      -4.413886
# 25%        -0.679713      -0.671586      -0.681683      -0.682738
# 50%        -0.004666       0.006482      -0.003919      -0.005722
# 75%         0.668339       0.681336       0.671642       0.672062
# max         3.926238       4.562115       4.219366       4.479084
#
#                   X5              y
# count  100000.000000  100000.000000
# mean        0.004148       3.591541
# std         0.997626       4.237751
# min        -4.157734     -23.979743
# 25%        -0.669534       0.999267
# 50%         0.002919       3.268183
# 75%         0.674960       5.866348
# max         4.202026      34.155924
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'AQI'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21404/1718459575.py in <module>
#      23     if column != "AQI":  # Suponiendo que "AQI" es la variable objetivo
#      24         plt.figure(figsize=(6, 4))
# ---> 25         sns.scatterplot(x=data[column], y=data["AQI"])
#      26         plt.xlabel(column)
#      27         plt.ylabel("AQI")
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'AQI'
